# %%
import pandas as pd
df = pd.read_csv("../data/superstore_raw.csv")

# STANDARDIZE COLUMN NAMES
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(r"[^\w]+", "_", regex=True) 
)

df.head()
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category        51290 non-null  object
#  1   city            51290 non-null  object
#  2   country         51290 non-null  object
#  3   customer_id     51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   discount        51290 non-null  float64
#  6   market          51290 non-null  object
#  7   order_date      51290 non-null  object
#  8   order_id        51290 non-null  object
#  9   order_priority  51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  product_name    51290 non-null  object
#  12  profit          51290 non-null  float64
#  13  quantity        51290 non-null  int64
#  14  region          51290 non-null  object
#  15  row_id          51290 non-null  int64
#  16  sales           51290 non-null  int64
# ...

# %%
df.columns.tolist()
# Out:
# ['category',
#  'city',
#  'country',
#  'customer_id',
#  'customer_name',
#  'discount',
#  'market',
#  'order_date',
#  'order_id',
#  'order_priority',
#  'product_id',
#  'product_name',
#  'profit',
#  'quantity',
#  'region',
#  'row_id',
#  'sales',
#  'segment',
#  'ship_date',
#  'ship_mode',
#  'shipping_cost',
#  'state',
#  'sub_category',
#  'year',
#  'market2',
#  'weeknum']

# %%
import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

# %%
from src.metrics_engine import compute_advanced_metrics
import pandas as pd

df = pd.read_csv("../data/superstore_raw.csv")

metrics = compute_advanced_metrics(df)

metrics["worst_performers"]
metrics["discount_analysis"]
# Out:
# c:\Users\shubu\Documents\AI-Driven Business Analyst Copilot for Profit Leakage Detection\Ai-business-analyst-copilot\src\metrics_engine.py:80: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("discount_bucket")
#   discount_bucket  total_sales  total_profit  order_count  profit_margin_pct
# 0           0-10%      8955367  2.108885e+06        17154          23.548834
# 1          10-20%      1757296  1.732548e+05         4363           9.859172
# 2          20-30%       382540 -2.115561e+04          843          -5.530301
# 3            30%+      1547702 -7.935265e+05         5794         -51.271270

# %%
metrics = compute_advanced_metrics(df)

metrics["profit_by_category"].head()
metrics["profit_by_sub_category"].head()
metrics["discount_analysis"]
metrics["worst_performers"]
# Out:
# c:\Users\shubu\Documents\AI-Driven Business Analyst Copilot for Profit Leakage Detection\Ai-business-analyst-copilot\src\metrics_engine.py:80: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("discount_bucket")
# {'worst_category': 'Furniture',
#  'worst_sub_category': 'Tables',
#  'worst_region': 'Canada',
#  'worst_segment': 'Home Office'}

# %%
metrics = compute_advanced_metrics(df)

# metrics["structural_collapse_by_category"].head()
# metrics["business_health"]
metrics["structural_collapse_by_category"]
# Out:
# c:\Users\shubu\Documents\AI-Driven Business Analyst Copilot for Profit Leakage Detection\Ai-business-analyst-copilot\src\metrics_engine.py:80: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("discount_bucket")
#           category  loss_periods  total_periods     avg_profit  \
# 0        Furniture             0              4   71301.180950
# 1  Office Supplies             0              4  129618.458575
# 2       Technology             0              4  165944.683295
#
#    loss_consistency_ratio
# 0                     0.0
# 1                     0.0
# 2                     0.0

# %%
from src.ai_reasoning import summarize_business

summary = summarize_business(metrics)
# print(summary)
summary
# Out:
# {'health_score': 77.32,
#  'profit_margin_pct': np.float64(11.61),
#  'loss_order_pct': 30.12,
#  'highest_risk_category': 'Furniture',
#  'highest_loss_ratio': np.float64(37.9),
#  'risk_level': 'High (Structural Inefficiency)'}

# %%
from src.ai_reasoning import summarize_business, generate_executive_summary

metrics = compute_advanced_metrics(df)
summary = summarize_business(metrics)

print(generate_executive_summary(summary))
# Out:
# Business Health Score: 77.32/100.
#
# Overall profit margin stands at 11.61%.
# However, 30.12% of orders are loss-making.
#
# The highest structural inefficiency is observed in the
# Furniture category, where approximately
# 37.9% of orders consistently generate losses.
#
# Risk Classification: High (Structural Inefficiency).
#
# Although aggregate profitability remains positive,
# margin concentration and pricing inefficiencies increase volatility risk.
# Strategic review of discounting, cost structure, and customer segmentation is recommended.
# c:\Users\shubu\Documents\AI-Driven Business Analyst Copilot for Profit Leakage Detection\Ai-business-analyst-copilot\src\metrics_engine.py:80: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("discount_bucket")

# %%
from src.ai_reasoning import answer_business_question

metrics = compute_advanced_metrics(df)

print(answer_business_question("What is our health score?", metrics))
print(answer_business_question("Which category has highest loss?", metrics))
print(answer_business_question("What is the risk level?", metrics))
# Out:
# The overall business health score is 77.32/100.
# The category with highest structural inefficiency is Furniture with approximately 37.9% loss-making orders.
# Risk classification is: High (Structural Inefficiency).
# c:\Users\shubu\Documents\AI-Driven Business Analyst Copilot for Profit Leakage Detection\Ai-business-analyst-copilot\src\metrics_engine.py:80: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("discount_bucket")

# %%
metrics = compute_advanced_metrics(df)

metrics["structural_inefficiency_by_category"]
# Out:
# c:\Users\shubu\Documents\AI-Driven Business Analyst Copilot for Profit Leakage Detection\Ai-business-analyst-copilot\src\metrics_engine.py:80: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("discount_bucket")
#           category  avg_loss_ratio  std_loss_ratio  periods_analyzed stability
# 0        Furniture        0.378970        0.008070                 4    Stable
# 1  Office Supplies        0.368081        0.006267                 4    Stable
# 2       Technology        0.292052        0.012591                 4    Stable
